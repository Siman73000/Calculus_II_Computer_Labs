# %% [markdown]
# <div style="display: flex; justify-content: space-between; align-items: center; border-bottom: 2px solid black; padding-bottom: 1em; font-family: 'Courier New', Courier, monospace;">
#     <h3 style="margin-top: 1em;">Calc/Analytic Geom II</h3>
#     <h3 style="text-align: center;">Computer Lab #4</h3>
#     <h3 style="justify-content: center; margin-right: 2em;">Simon Hamilton</h3>
# </div>

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_VU2NWDptQ8UIPg5pntXB0mQ3HMJ56NBdjQ&s"
#      alt="Calc_Image"
#      width="400"
#      height="330"
#      style="float:right; border: 8px solid #737373ff; border-radius: 20px; margin-left: 1em; margin-right: 5em;">
#
# <p style="font-size: 1em; overflow-wrap: normal; font-family: 'Courier New', Courier, monospace;">
#   This programming lab will cover topics of Bessel functions, convergence, and parametric curves.
#   The Bessel function is used to describe vibrations of a circular membrane (as shown in the picture).
# </p>
#
# <p style="font-size: 1em; overflow-wrap: normal; font-family: 'Courier New', Courier, monospace;">
#   I'm asked to consider the function below as $a=8$. $$J_a(x)=\sum_{n=0}^{\infty}\frac{(-1)^nx^{2n+a}}{n!(n+a)!2^{2n+a}}$$
# </p>

# %% [markdown]
# <div>
#     <p style="border-top: 2px solid black; padding-top: 2em; font-family: 'Courier New', Courier, monospace;">
#     For that first problem, I'll start by finding the interval of convergence, then I'll graph the sum.</p>
# </div>

# %% [markdown]
# <div style="max-width:920px;margin:0 auto;background:linear-gradient(180deg,#061021 0%,#071833 100%);color:#e6eef6;font-family:Inter,ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,'Helvetica Neue',Arial;padding:28px;line-height:1.6;">
#   <div style="font-size:20px;margin-bottom:10px;color:#7dd3fc;">Bessel Function of the First Kind</div>
#   <div style="color:#94a3b8;font-size:13px;margin-bottom:18px;">Series convergence and partial-sum approximations for \(a = 8\)</div>
#
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:24px;border:1px solid rgba(255,255,255,0.06);">
#     Let \(a = 8\). Consider the Bessel function of the first kind
#     \[
#       J_a(x) = \sum_{n=0}^{\infty} \frac{(-1)^n x^{2n+a}}{n!(n+a)!\,2^{2n+a}}.
#     \]
#     For \(a = 8\) this becomes
#     \[
#       J_8(x) = \sum_{n=0}^{\infty} \frac{(-1)^n x^{2n+8}}{n!(n+8)!\,2^{2n+8}}.
#     \]
#   </div>
#
#   <!-- PART (a) -->
#   <div style="background:rgba(255,255,255,0.02);border:1px solid rgba(125,211,252,0.06);border-radius:12px;padding:20px;margin-bottom:24px;box-shadow:0 6px 30px rgba(2,6,23,0.6);">
#     <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;font-weight:700;color:#e6f6ff;">
#       <div style="width:10px;height:10px;background:#7dd3fc;border-radius:4px;"></div>
#       <div>TASK (a) – Interval of Convergence via the Ratio Test</div>
#     </div>
#
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#       We write the series as
#       \[
#         J_8(x) = \sum_{n=0}^{\infty} a_n(x),
#         \qquad
#         a_n(x) = \frac{(-1)^n x^{2n+8}}{n!(n+8)!\,2^{2n+8}}.
#       \]
#       To find the interval of convergence, we apply the Ratio Test to the general term \(a_n(x)\).
#   </div>
#
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#       We consider
#       \[
#         \left|\frac{a_{n+1}(x)}{a_n(x)}\right|
#         = \left|
#           \frac{(-1)^{n+1} x^{2(n+1)+8}}{(n+1)!(n+9)!\,2^{2(n+1)+8}}
#           \cdot
#           \frac{n!(n+8)!\,2^{2n+8}}{(-1)^n x^{2n+8}}
#         \right|.
#       \]
#       Simplifying step by step:
#       \[
#         x^{2(n+1)+8} = x^{2n+10} = x^{2n+8}\,x^2,
#       \]
#       \[
#         \frac{n!}{(n+1)!} = \frac{1}{n+1}, \qquad
#         \frac{(n+8)!}{(n+9)!} = \frac{1}{n+9},
#       \]
#       \[
#         \frac{2^{2n+8}}{2^{2n+10}} = \frac{1}{2^2} = \frac{1}{4}.
#       \]
#       Therefore
#       \[
#         \left|\frac{a_{n+1}(x)}{a_n(x)}\right|
#         = |x|^2 \cdot \frac{1}{n+1} \cdot \frac{1}{n+9} \cdot \frac{1}{4}
#         = \frac{|x|^2}{4(n+1)(n+9)}.
#       \]
#       Now take the limit as \(n \to \infty\):
#       \[
#         \lim_{n \to \infty}
#         \left|\frac{a_{n+1}(x)}{a_n(x)}\right|
#         = \lim_{n \to \infty} \frac{|x|^2}{4(n+1)(n+9)} = 0
#       \]
#       for every real number \(x\). Since \(0 &lt; 1\), the Ratio Test tells us that the series
#       \(\sum_{n=0}^{\infty} a_n(x)\) converges (in fact, absolutely) for all real \(x\).
#   </div>
#
#   <div style="color:#94a3b8;font-size:13px;">
#       <strong>Conclusion:</strong> The power series for \(J_8(x)\) converges for every real number \(x\).<br>
#       The interval of convergence is
#       \[
#         (-\infty, \infty),
#       \]
#       so the radius of convergence is \(R = \infty\).
#   </div>
#   </div>
#
#   <!-- PART (b) -->
#   <div style="background:rgba(255,255,255,0.02);border:1px solid rgba(125,211,252,0.06);border-radius:12px;padding:20px;margin-bottom:24px;box-shadow:0 6px 30px rgba(2,6,23,0.6);">
#     <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;font-weight:700;color:#e6f6ff;">
#       <div style="width:10px;height:10px;background:#ffd166;border-radius:4px;"></div>
#       <div>TASK (b) – Graph Partial Sums for Different Truncation Levels</div>
#     </div>
#     <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#       For each choice \(b = 1,\;10,\;50\), define the partial sum
#       \[
#         S_b(x) = \sum_{n=0}^{b} \frac{(-1)^n x^{2n+8}}{n!(n+8)!\,2^{2n+8}}.
#       \]
#       Plot \(S_b(x)\) on the same axes for the domain
#       \[
#         0 \le x \le 10.
#       \]
#       That is, for each \(b \in \{1,10,50\}\), graph the corresponding partial sum over this interval.
#     </div>
#     <div style="color:#94a3b8;font-size:13px;">
#       Your plots should clearly label which curve corresponds to each value of \(b\).
#     </div>
#   </div>
#
#   <!-- PART (c) -->
#   <div style="background:rgba(255,255,255,0.02);border:1px solid rgba(125,211,252,0.06);border-radius:12px;padding:20px;margin-bottom:24px;box-shadow:0 6px 30px rgba(2,6,23,0.6);">
#     <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;font-weight:700;color:#e6f6ff;">
#       <div style="width:10px;height:10px;background:#7cf6a4;border-radius:4px;"></div>
#       <div>TASK (c) – Compare Partial Sums with the Full Bessel Function</div>
#     </div>
#     <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#       On the same coordinate axes, plot:
#       \[
#         S_1(x),\; S_{10}(x),\; S_{50}(x)
#       \]
#       together with the “exact” Bessel function \(J_8(x)\).<br><br>
#       Use a suitable numerical library or plotting tool to evaluate \(J_8(x)\) and to overlay all four curves on the interval
#       \[
#         0 \le x \le 10.
#       \]
#       Make sure the axes and legend are clearly labeled so that each curve can be identified.
#     </div>
#     <div style="color:#94a3b8;font-size:13px;">
#       Use consistent axes and sufficient resolution in \(x\) to see the oscillatory behavior of \(J_8(x)\).
#     </div>
#   </div>
#
#   <!-- PART (d) -->
#   <div style="background:rgba(255,255,255,0.02);border:1px solid rgba(125,211,252,0.06);border-radius:12px;padding:20px;margin-bottom:8px;box-shadow:0 6px 30px rgba(2,6,23,0.6);">
#     <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;font-weight:700;color:#e6f6ff;">
#       <div style="width:10px;height:10px;background:#f97373;border-radius:4px;"></div>
#       <div>TASK (d) – Describe the Quality of the Approximation</div>
#     </div>
#     <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#       For each integer \(b \ge 0\), the partial sum
#       \[
#         S_b(x) = \sum_{n=0}^{b} \frac{(-1)^n x^{2n+8}}{n!(n+8)!\,2^{2n+8}}
#       \]
#       approximates the full Bessel function \(J_8(x)\). Since the series has infinite radius of convergence, we have
#       \[
#         \lim_{b \to \infty} S_b(x) = J_8(x)
#       \]
#       for every fixed real \(x\). Thus the approximation improves as \(b\) increases.
#       <br><br>
#       Near \(x = 0\), the higher powers \(x^{2n+8}\) are very small, so only a few terms are needed for a good approximation: even small values of \(b\) give \(S_b(x)\) very close to \(J_8(x)\) near the origin. For larger values of \(x\), more terms are required before the alternating series and factorials in the denominator dominate; as \(b\) increases, the partial sums capture more of the oscillatory behavior of \(J_8(x)\), and the amplitudes and zeros of \(S_b(x)\) line up more closely with those of the full function.
#     </div>
#     <div style="color:#94a3b8;font-size:13px;">
#       In summary, the partial sums \(S_b(x)\) converge to \(J_8(x)\) for all real \(x\), with especially rapid convergence near \(x = 0\) and increasingly accurate approximation on \(0 \le x \le 10\) as the truncation level \(b\) grows.
#     </div>
#   </div>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # registers 3D projection
from scipy.special import jv
import math

a = 8
x_min, x_max = 0.0, 10.0
num_x = 400
b_max = 50

x = np.linspace(x_min, x_max, num_x)

def bessel_partial_sum(a, x, b):
    x = np.asarray(x, dtype=float)
    S = np.zeros_like(x, dtype=float)

    for n in range(b + 1):
        coef = ((-1)**n) / (math.factorial(n) * math.factorial(n + a) * 2.0**(2*n + a))
        S += coef * x**(2*n + a)

    return S


S_rows = []
for b in range(b_max + 1):
    S_rows.append(bessel_partial_sum(a, x, b))

S = np.vstack(S_rows)

B_indices = np.arange(0, b_max + 1)
X, B = np.meshgrid(x, B_indices)
J_exact = jv(a, x)
fig = plt.figure(figsize=(11, 7))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(
    X, B, S,
    cmap='viridis',
    linewidth=0,
    antialiased=True,
    alpha=0.85
)

highlight_bs = [1, 10, 50]
for b in highlight_bs:
    ax.plot(
        x,
        np.full_like(x, b, dtype=float),
        S[b],
        linewidth=2,
        label=fr'$S_{b}(x)$'
    )

b_exact_level = b_max + 5
ax.plot(
    x,
    np.full_like(x, b_exact_level, dtype=float),
    J_exact,
    color='red',
    linewidth=3,
    label=r'$J_8(x)$'
)

ax.set_xlabel(r'$x$', labelpad=10)
ax.set_ylabel(r'Number of terms $b$', labelpad=10)
ax.set_zlabel(r'$S_b(x)$ or $J_8(x)$', labelpad=10)
ax.set_title(r'3D View of Partial Sums $S_b(x)$ Approaching $J_8(x)$', pad=15)
cbar = fig.colorbar(surf, ax=ax, shrink=0.6, aspect=14)
cbar.set_label(r'$S_b(x)$', rotation=90, labelpad=10)
ax.view_init(elev=30, azim=-60)
ax.legend(loc='upper left', bbox_to_anchor=(1.02, 1.0))

plt.tight_layout()
plt.show()

# %% [markdown]
# <div>
#     <p style="font-family: 'Courier New', Courier, monospace; margin-top: 2em; margin-bottom: 2em; border-bottom: solid black 2px; padding-bottom: 2em;">
#         The next question asks to consider the Lissajous figure. I'll use the same definition of $a=8$ and $b$ from above. The variable $t$ though, varies between 0 and $2\pi$.
#         $$\begin{matrix*}
#         x=a\sin{(3t)} \\
#         y=b\cos{(t)}
#         \end{matrix*}$$
#     </p>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import gamma, factorial

class FactorialPlot:
    def __init__(self, a=8, x_min=0, x_max=20, num_points=400):
        self.a = a
        self.x_min = x_min
        self.x_max = x_max
        self.num_points = num_points
        self.x_discrete = np.arange(self.x_min, self.x_max + 1)
        self.x_continuous = np.linspace(self.x_min, self.x_max, self.num_points)
        self.g_discrete = self.compute_discrete(self.x_discrete)
        self.g_continuous = self.compute_continuous(self.x_continuous)
        self.peak_x = self.x_discrete[np.argmax(self.g_discrete)]
        self.x_large = np.arange(50, 200, 10)
        self.g_values = self.x_large**a / factorial(self.x_large)
        self.styles = {
            "figsize": (10, 6),
            "continuous": {"color": "#1f77b4", "linewidth": 3, "alpha": 0.7, "label": "Gamma extension (continuous)"},
            "discrete": {"color": "#ff7f0e", "s": 100, "edgecolor": "k", "zorder": 5, "label": "Discrete factorial points"},
            "grid": {"which": "both", "linestyle": "--", "linewidth": 0.5, "alpha": 0.5},
            "title": {"fontsize": 16, "color": "#2ca02c"},
            "xlabel": {"fontsize": 14, "fontweight": "bold"},
            "ylabel": {"fontsize": 14, "fontweight": "bold"},
            "legend": {"frameon": True, "shadow": True, "fontsize": 12},
            "peak_line": {"color": "purple", "linestyle": ":", "linewidth": 2, "label": "Peak value"}
        }

    def compute_discrete(self, x):
        return x**self.a / factorial(x)

    def compute_continuous(self, x):
        return x**self.a / gamma(x + 1)
    
    def plot(self, title=None):
        plt.figure(figsize=self.styles["figsize"])
        plt.plot(self.x_continuous, self.g_continuous, **self.styles["continuous"])
        plt.scatter(self.x_discrete, self.g_discrete, **self.styles["discrete"])
        plt.axvline(x=self.peak_x, **self.styles["peak_line"])
        plt.grid(**self.styles["grid"])
        plt.xlabel("x", **self.styles["xlabel"])
        plt.ylabel("g(x)", **self.styles["ylabel"])
        if title is None:
            title = f"Plot of g(x)=x^{self.a} / x! for {self.x_min} ≤ x ≤ {self.x_max}"
        plt.title(title, **self.styles["title"])
        plt.legend(**self.styles["legend"])
        plt.minorticks_on()
        plt.tight_layout()
        plt.show()
    
    def lim_estimate(self):
        print(f"Estimating lim x→∞ g(x) = x^{self.a} / x!")
        for x, g in zip(self.x_large, self.g_values):
            print(f"x = {x:3}, g(x) = {g:.3e}")
        print("\nObservation: As x increases, g(x) approaches 0.")
        print(f"Estimated limit ≈ {self.g_values[-1]:.3e}")

    def formal_limit_N(self, epsilon=None):
        if epsilon is None:
            epsilon = 1 / self.a**3
        x = self.a
        while True:
            g = x**self.a / factorial(x)
            if g < epsilon:
                N = x
                break
            x += 1
        print(f"Formal ε-N limit check:")
        print(f"ε = {epsilon:.3e}")
        print(f"Smallest N such that |g(x)| < ε for all x > N: N = {N}")
        return N

plotter = FactorialPlot(a=8, x_max=20)
plotter.plot()
plotter.lim_estimate()
N = plotter.formal_limit_N()
# Out:
# Estimating lim x→∞ g(x) = x^8 / x!
# x =  50, g(x) = 1.284e-51
# x =  60, g(x) = 2.019e-68
# x =  70, g(x) = 4.813e-86
# x =  80, g(x) = 2.344e-104
# x =  90, g(x) = 2.897e-123
# x = 100, g(x) = 1.072e-142
# x = 110, g(x) = 1.350e-162
# x = 120, g(x) = 6.428e-183
# x = 130, g(x) = 1.261e-203
# x = 140, g(x) = 1.096e-224
# x = 150, g(x) = 4.486e-246
# x = 160, g(x) = 9.110e-268
# x = 170, g(x) = 9.612e-290
# x = 180, g(x) = 0.000e+00
# x = 190, g(x) = 0.000e+00
#
# Observation: As x increases, g(x) approaches 0.
# Estimated limit ≈ 0.000e+00
# Formal ε-N limit check:
# ε = 1.953e-03
# Smallest N such that |g(x)| < ε for all x > N: N = 16

# %% [markdown]
# <div>
#     <p style="font-family: 'Courier New', Courier, monospace; margin-top: 2em; margin-bottom: 2em; border-bottom: solid black 2px; padding-bottom: 2em;">
#         The final question asks to consider the series $$\sum_{n=1}^{\infty} \frac{(\ln(n))^2}{n^2}$$
#     </p>
# </div>
# <div>
#     <p style="font-family: 'Courier New', Courier, monospace; margin-top: 2em; margin-bottom: 2em; border-bottom: solid black 2px; padding-bottom: 2em;">
#         The Python code below shows that the series is convergent, $S$. It also prints the error in $S \approx S_a$, $S \approx S_{a+100}$, and $S \approx S_{a+1000}$.
#     </p>
# </div>

# %%
class LogSquaredSeries:
    def __init__(self, a):
        self.a = a
        self.n_values = np.arange(1, self.a + 1)
        self.S_a = self.compute_partial_sum()
        self.error_bound = self.compute_error_bound()
    
    def term(self, n):
        return (np.log(n))**2 / n**2
    
    def compute_partial_sum(self, n_max=None):
        if n_max is None:
            n_max = self.a
        n_values = np.arange(1, n_max + 1)
        return np.sum(self.term(n_values))
    
    def compute_error_bound(self, start=None):
        if start is None:
            start = self.a
        ln_start = np.log(start)
        return (ln_start**2 + 2*ln_start + 2) / start
    
    def summary(self):
        print(f"Partial sum S_{self.a} = {self.S_a:.6f}")
        print(f"Estimated error |S - S_{self.a}| ≤ {self.error_bound:.6f}")
    
    def error_for_offset(self, k_values):
        for k in k_values:
            n_new = self.a + k
            S_new = self.compute_partial_sum(n_new)
            error_new = self.compute_error_bound(n_new)
            print(f"S_{self.a}+{k} = S_{n_new} ≈ {S_new:.6f}, estimated error ≤ {error_new:.6f}")

series = LogSquaredSeries(a=10)
series.summary()
series.error_for_offset([100, 1000])
# Out:
# Partial sum S_10 = 0.824583
# Estimated error |S - S_10| ≤ 1.190707
# S_10+100 = S_110 ≈ 1.685687, estimated error ≤ 0.304504
# S_10+1000 = S_1010 ≈ 1.926244, estimated error ≤ 0.063059

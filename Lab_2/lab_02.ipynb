# %% [markdown]
# <div style="display: flex; justify-content: space-between; align-items: center; border-bottom: 2px solid black; padding-bottom: 1em; font-family: 'Courier New', Courier, monospace;">
#     <h3 style="margin-top: 1em;">Calc/Analytic Geom II</h3>
#     <h3 style="text-align: center;">Computer Lab #2</h3>
#     <h3 style="justify-content: center; margin-right: 2em;">Simon Hamilton</h3>
# </div>

# %% [markdown]
# <img src="https://preview.redd.it/ftcjd1m8hbq31.jpg?auto=webp&s=5a5090e9f9f3129cabd461636c1f6860a7ae228e"
#      alt="Calc_Image"
#      style="float: right; width: 400px; height: 400px; margin-left: 1em; margin-right: 5em; margin-top: -0.5em;">
#
# <p style="font-size: 1em; overflow-wrap: normal; font-family: 'Courier New', Courier, monospace;">
#   This programming lab will cover topics of partial fraction decomposition, definite and improper integration, and curve sketching. The first function given (shown below) requires partial fraction decomposition as asked in the problem further down. $$ h(x) = \frac{4x^3 - 27x^2 + 5x - 32}{30x^5 - 13x^4 + 50x^3 - 286x^2 - 299x - 70} $$
# </p>
#
# <p style="font-size: 1em; overflow-wrap: normal; font-family: 'Courier New', Courier, monospace;">
#   The first subquestion of this problem is to find the partial fraction decomposition.
#   Partial fraction decomposition refers to a method of solving for $A$, $B$, and/or $C$ variables.
#   These help break the problem down into one that's much easier to interpret.
# </p>

# %% [markdown]
# <div>
#     <p style="border-top: 2px solid black; padding-top: 2em; font-family: 'Courier New', Courier, monospace;">
#     For that first problem, I'll start with the partial fraction decomposition.
#     Once found, I'm going to integrate using what the program found (also computed by hand for QA).</p>
# </div>

# %% [markdown]
# <div style="max-width:920px;margin:0 auto;background:linear-gradient(180deg,#061021 0%,#071833 100%);color:#e6eef6;font-family:Inter,ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,'Helvetica Neue',Arial;padding:28px;line-height:1.6;">
# <div style="font-size:20px;margin-bottom:10px;color:#7dd3fc;">Partial Fraction Decomposition - Step by Step</div>
# <div style="color:#94a3b8;font-size:13px;margin-bottom:18px;">Rational integrand</div>
# <div style="background:rgba(255,255,255,0.02);border:1px solid rgba(125,211,252,0.06);border-radius:12px;padding:20px;margin-bottom:24px;box-shadow:0 6px 30px rgba(2,6,23,0.6);">
#   <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;font-weight:700;color:#e6f6ff;">
#     <div style="width:10px;height:10px;background:#7dd3fc;border-radius:4px;"></div>
#     <div>STEP 1 - Factor the denominator</div>
#   </div>
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#     \( \displaystyle
#       \text{Integrand: }
#       \frac{4x^{3}-27x^{2}+5x-32}{30x^{5}-13x^{4}+50x^{3}-286x^{2}-299x-70}
#     \)
#   </div>
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#     Factor the denominator:
#     \[
#       30x^{5}-13x^{4}+50x^{3}-286x^{2}-299x-70
#       = (2x+1)(3x-7)(5x+2)(x^{2}+x+5)
#     \]
#   </div>
#   <div style="color:#94a3b8;font-size:13px;">
#     So now decompose with linear factors \(2x+1,\,3x-7,\,5x+2\) and the irreducible quadratic \(x^{2}+x+5\).
#   </div>
# </div>
# <div style="background:rgba(255,255,255,0.02);border:1px solid rgba(125,211,252,0.06);border-radius:12px;padding:20px;margin-bottom:24px;box-shadow:0 6px 30px rgba(2,6,23,0.6);">
#   <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;font-weight:700;color:#e6f6ff;">
#     <div style="width:10px;height:10px;background:#ffd166;border-radius:4px;"></div>
#     <div>STEP 2 - Partial fraction setup and solved coefficients</div>
#   </div>
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#     Set up the decomposition:
#     \[
#       \frac{4x^{3}-27x^{2}+5x-32}{(2x+1)(3x-7)(5x+2)(x^{2}+x+5)}
#       = \frac{A}{2x+1}+\frac{B}{3x-7}+\frac{C}{5x+2}+\frac{Dx+E}{x^{2}+x+5}
#     \]
#   </div>
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#     Solving for constants:
#   </div>
#   <div style="display:grid;grid-template-columns:repeat(auto-fit,minmax(220px,1fr));gap:2em;margin-top:1em;margin-bottom:1em;">
#     <div style="background:rgba(255,255,255,0.02);padding:1em;border-radius:8px;border:1px solid rgba(125,211,252,0.04);">
#       \(\displaystyle A=-\frac{668}{323}\)
#       <div style="color:#94a3b8;font-size:13px;margin-top:8px;">term: \( \frac{A}{2x+1}\)</div>
#     </div>
#     <div style="background:rgba(255,255,255,0.02);padding:1em;border-radius:8px;border:1px solid rgba(125,211,252,0.04);">
#       \(\displaystyle B=-\frac{9438}{80155}\)
#       <div style="color:#94a3b8;font-size:13px;margin-top:8px;">term: \( \frac{B}{3x-7}\)</div>
#     </div>
#     <div style="background:rgba(255,255,255,0.02);padding:1em;border-radius:8px;border:1px solid rgba(125,211,252,0.04);">
#       \(\displaystyle C=\frac{24110}{4879}\)
#       <div style="color:#94a3b8;font-size:13px;margin-top:8px;">term: \( \frac{C}{5x+2}\)</div>
#     </div>
#     <div style="background:rgba(255,255,255,0.02);padding:1em;border-radius:8px;border:1px solid rgba(125,211,252,0.04);">
#       \(\displaystyle D=\frac{22098}{260015}\)
#       <div style="color:#94a3b8;font-size:13px;margin-top:8px;">quadratic numerator coefficient of \(x\)</div>
#     </div>
#     <div style="background:rgba(255,255,255,0.02);padding:1em;border-radius:8px;border:1px solid rgba(125,211,252,0.04);">
#       \(\displaystyle E=\frac{9787}{52003}\)
#       <div style="color:#94a3b8;font-size:13px;margin-top:8px;">quadratic numerator constant</div>
#     </div>
#   </div>
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#     So the decomposition is:
#     \[
#       \frac{4x^{3}-27x^{2}+5x-32}{\dots}
#       = -\frac{668}{323(2x+1)}
#         -\frac{9438}{80155(3x-7)}
#         +\frac{24110}{4879(5x+2)}
#         +\frac{\tfrac{22098}{260015}x+\tfrac{9787}{52003}}{x^{2}+x+5}
#     \]
#   </div>
# </div>
# <div style="background:rgba(255,255,255,0.02);border:1px solid rgba(125,211,252,0.06);border-radius:12px;padding:20px;margin-bottom:24px;box-shadow:0 6px 30px rgba(2,6,23,0.6);">
#   <div style="display:flex;align-items:center;gap:12px;margin-bottom:14px;font-weight:700;color:#e6f6ff;">
#     <div style="width:10px;height:10px;background:#7cf6a4;border-radius:4px;"></div>
#     <div>STEP 3 - Integrate each term</div>
#   </div>
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#     Integrate term-by-term:
#     \[
#       \int \frac{A}{2x+1}\,dx=\frac{A}{2}\ln|2x+1|,\quad
#       \int\frac{B}{3x-7}\,dx=\frac{B}{3}\ln|3x-7|,\quad
#       \int\frac{C}{5x+2}\,dx=\frac{C}{5}\ln|5x+2|
#     \]
#   </div>
#   <div style="background:#071025;border-radius:8px;padding:16px;font-family:'Courier New',monospace;white-space:pre-wrap;margin-bottom:18px;border:1px solid rgba(255,255,255,0.03);">
#     For the quadratic term write \(Dx+E=\tfrac{D}{2}(2x+1)+(E-\tfrac{D}{2})\):
#     \[
#       \int\frac{Dx+E}{x^{2}+x+5}\,dx
#       = \frac{D}{2}\ln(x^{2}+x+5)
#         +(E-\tfrac{D}{2})\int\frac{dx}{x^{2}+x+5}
#     \]
#     Completing the square:
#     \(x^{2}+x+5=(x+\tfrac12)^{2}+\tfrac{19}{4}\), so
#     \[
#       \int\frac{dx}{x^{2}+x+5}
#       = \frac{2}{\sqrt{19}}\arctan\!\Big(\frac{2x+1}{\sqrt{19}}\Big)
#     \]
#   </div>
#   <div style="background:linear-gradient(180deg,rgba(34,197,94,0.03),rgba(14,42,20,0.02));border:1px solid rgba(34,197,94,0.06);border-radius:8px;padding:16px;margin-top:20px;">
#     <strong>Final antiderivative:</strong>
#     \[
#       \boxed{\,\begin{aligned}
#         \int &\frac{4x^{3}-27x^{2}+5x-32}{30x^{5}-13x^{4}+50x^{3}-286x^{2}-299x-70}\,dx \;=\\[6pt]
#         &-\frac{334}{323}\ln|2x+1|
#         -\frac{3146}{80155}\ln|3x-7|
#         +\frac{4822}{4879}\ln|5x+2|\\[6pt]
#         &\quad+\frac{11049}{260015}\ln(x^{2}+x+5)
#         +\frac{3988\sqrt{19}}{260015}\arctan\!\Big(\frac{2x+1}{\sqrt{19}}\Big)+C.
#       \end{aligned}}
#     \]
#   </div>
#   <div style="color:#94a3b8;font-size:13px;margin-top:12px;">
#     Equivalent rationalized coefficient form:
#     \(\frac{3988}{13685\sqrt{19}}=\frac{3988\sqrt{19}}{260015}\).
#   </div>
# </div>
# </div>

# %%
import sympy as sp
from sympy import init_printing

x = sp.Symbol('x')
expr = (4*x**3 - 27*x**2 + 5*x - 32) / (30*x**5 - 13*x**4 + 50*x**3 - 286*x**2 - 299*x - 70)
integral = sp.integrate(expr, x)

init_printing(use_unicode=True)
integral
# Out:
#                                                                                ↪
#                                                                       ⎛ 2      ↪
#   3146⋅log(x - 7/3)   4822⋅log(x + 2/5)   334⋅log(x + 1/2)   11049⋅log⎝x  + x  ↪
# - ───────────────── + ───────────────── - ──────────────── + ───────────────── ↪
#         80155               4879                323                 260015     ↪
#
# ↪                     ⎛2⋅√19⋅x   √19⎞
# ↪    ⎞   3988⋅√19⋅atan⎜─────── + ───⎟
# ↪ + 5⎠                ⎝  19      19 ⎠
# ↪ ──── + ────────────────────────────
# ↪                   260015

# %% [markdown]
# <div>
#     <p style="font-family: 'Courier New', Courier, monospace; margin-top: 2em;">
#         The second question asks to consider $g(x)=\frac{cos^2{x}}{x^2}$.
#     </p>
# </div>
# <div>
#     <p style="font-family: 'Courier New', Courier, monospace; margin-top: 2em;">
#         Using that equation, I'll compute $\[ \int_{1}^{t} g(x) \, dx\]$ for $t=2, 5, 10, 100, 1000, 10000$.
#     </p>
# </div>

# %%
plt.plot(x, y, label="f(x)")

plt.fill_between(x, y, color="skyblue", alpha=0.4, label="Area under curve")

plt.scatter([0, 10], [f(0), f(10)], color="red", zorder=5)
plt.text(0, f(0) + 0.05, f"(0, {f(0):.2f})", ha="right", va="bottom")
plt.text(8.9, f(10) + 0.05, f"(10, {f(10):.2f})", ha="left", va="bottom")

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title(r"AUC of $f(x) = \frac{1}{\sqrt{6x + 1}}$")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div>
#     <p style="font-family: 'Courier New', Courier, monospace; margin-top: 2em;">This is an additional way to graph the AUC of our function using a very common Machine Learning package scikit-learn. This package has a built in AUC metric that we can call to compute this area. Once computed we can simply graph it with pyplot.</p>
# </div>

# %%
from sklearn.metrics import auc
area = auc(x, y)
plt.plot(x, y, label="f(x)")
plt.fill_between(x, y, color="skyblue", alpha=0.4, label=f"AUC = {area:.3f}")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title(r"AUC of $f(x) = \frac{1}{\sqrt{6x + 1}}$")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div>
#     <p style="border-top: 2px solid black; padding-top: 2em; font-family: 'Courier New', Courier, monospace;">
#     The second question asks to consider the functions, where $ a $ is as defined above,
#     $$
#     \begin{aligned}
#     y=e^{x} \quad
#     \text{and} \quad
#     y=\sqrt{ax}+1
#     \end{aligned}
#     $$
#     The first subquestion asks for both these functions to be graphed on the same coordinate axis. I will do this in the way I've done it before. With pyplot! Yipee!
#     I am combining the answers to the other subquestions into this graph as this will decrease the need for a million different graphs. Anyways, the second subquestion asks to find the points of intersection using the numerical solver and manual inspection of the graph. I was able to complete this using Python and my eyeballs to see the graph.
#     </p>
# </div>

# %%
from scipy.optimize import fsolve
from scipy.integrate import quad

x = np.linspace(0, 2, 400)

func_01 = lambda x: np.exp(x)
func_02 = lambda x: np.where(x >= 0, np.sqrt(a * x) + 1, np.nan)

def intersection(x):
    return func_01(x) - func_02(x)

# eyeball guess
init_x_guesstimate = [0, 1.3]
x_intersections = [fsolve(intersection, x0)[0] for x0 in init_x_guesstimate]
y_intersections = [func_01(xi) for xi in x_intersections]

x_start, x_end = x_intersections
auc_func01, _ = quad(func_01, x_start, x_end)
auc_func02, _ = quad(func_02, x_start, x_end)

plt.figure(figsize=(8,6))
plt.plot(x, func_01(x), label=r"$y=e^x$", color="blue", linewidth=2)
plt.plot(x, func_02(x), label=rf"$y=\sqrt{{{a}x}}+1$", color="green", linewidth=2)
plt.scatter(x_intersections, y_intersections, color="red", zorder=5, label="Intersections")

x_fill = np.linspace(x_start, x_end, 400)
plt.fill_between(
    x_fill,
    func_01(x_fill),
    func_02(x_fill),
    color="red",
    alpha=0.3,
    label="Area Between Curves"
)

for xi, yi in zip(x_intersections, y_intersections):
    plt.text(xi, yi + 0.5, f"({xi:.2f},{yi:.2f})", fontsize=10, ha="left", va="bottom")

ax = plt.gca()
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title(r"Intersection of $y=e^x$ and $y=\sqrt{ax}+1$")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.show()

report_lines = [
    "Intersection Points",
    f"  x1 = {x_intersections[0]:.4f}, y1 = {y_intersections[0]:.4f}",
    f"  x2 = {x_intersections[1]:.4f}, y2 = {y_intersections[1]:.4f}",
    "",
    "AUC Between Intersections",
    f"  Under y = e^x          : {auc_func01:.4f}",
    f"  Under y = sqrt({a}*x)+1 : {auc_func02:.4f}",
    f"  Difference (e^x - sqrt({a}x)+1) : {auc_func01 - auc_func02:.4f}",
]

print("\n".join(report_lines))
# Out:
# Intersection Points
#   x1 = 0.0000, y1 = 1.0000
#   x2 = 1.3459, y2 = 3.8418
#
# AUC Between Intersections
#   Under y = e^x          : 2.8418
#   Under y = sqrt(6*x)+1 : 3.8958
#   Difference (e^x - sqrt(6x)+1) : -1.0540

# %% [markdown]
# <style>
#     .threed-graph-description p {
#         font-family: 'Courier New', Courier, monospace;
#         border-top: 2px solid black;
#         padding-top: 2em;
#     }
# </style>
# <div class="threed-graph-description">
#     <p style="font-family: 'Courier New', Courier, monospace; border-top: 2px solid black; padding-top: 2em;">
#         The last portion of the second question asks to calculate the volume of the solid obtained by rotating about the y-axis.
#         Seeing that we're rotating about the y-axis, I knew to use the Shell method.
#         $$ V = 2\pi \int abx f(x) \, dx $$
#     </p>
# </div>

# %%
from mpl_toolkits.mplot3d import Axes3D

# this is where the actual integration is defined for the shell method
integrand = lambda x: 2 * np.pi * x * (func_02(x) - func_01(x))
volume, _ = quad(integrand, x_start, x_end)
print(f"Volume: {volume:.4f}")

theta = np.linspace(0, 2*np.pi, 150)
x_vals = np.linspace(x_start, x_end, 150)
X, T = np.meshgrid(x_vals, theta)

def surface_coords(f):
    Y = f(X)
    Z = X * np.cos(T)
    Xc = X * np.sin(T)
    return Xc, Z, Y

X_outer, Z_outer, Y_outer = surface_coords(func_02)
X_inner, Z_inner, Y_inner = surface_coords(func_01)

fig = plt.figure(figsize=(12,7))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X_outer, Z_outer, Y_outer,
                color='green', alpha=0.5, edgecolor='k', rstride=5, cstride=5, linewidth=0.5)

ax.plot_surface(X_inner, Z_inner, Y_inner,
                color='blue', alpha=0.5, edgecolor='k', rstride=5, cstride=5, linewidth=0.5)

for xi in np.linspace(x_start, x_end, 6):
    ax.plot([0,0], [0,0], [func_01(xi), func_02(xi)], color='red', lw=2)

ax.set_title("3D Volume Graph of the y-axis Rotation", fontsize=16)
ax.set_xlabel("X (rotation)")
ax.set_ylabel("Z (rotation)")
ax.set_zlabel("Y (height)", fontsize=12)
ax.view_init(elev=30, azim=-60)
ax.grid(True)

plt.show()
# Out:
# Volume: 3.9958

# %% [markdown]
# <style>
#     .additional-bottom-text p {
#         margin-top: 2em;
#         font-family: 'Courier New', Courier, monospace;
#     }
#     .additional-top-text {
#         margin-top: 2em;
#         font-family: 'Courier New', Courier, monospace;
#     }
#     .what-the-sigma {
#         margin-top: 2em;
#         font-family: 'Couier', Courier, monospace;
#     }
# </style>
# <div class="additional-top-text">
#     <p style="font-family: 'Courier New', Courier, monospace;">
#         The third and final question asks to use integration by parts to prove the following reduction formula:
#         $$ \int (\ln{x})^n \, dx = x (\ln{x})^n - n \int (\ln{x})^{n-1} \, dx$$
#     </p>
# </div>
#
# <div class="additional-bottom-text">
#     <p style="font-family: 'Courier New', Courier, monospace;">
#         First I need to find the integral on the left-hand-side when $n\space =\space a$. The answer can be seen below.
#         $$ \int (\ln{x})^6 \, dx = x(\ln{x})^6 - 6x(\ln{x})^5 + 30x(\ln{x})^3 + 360x(\ln{x})^2 - 720x\ln{x} + 720x + C$$
#     </p>
# </div>
#
# <div class="what-the-sigma">
#     <p style="font-family: 'Courier New', Courier, monospace;">
#        The reduction formula is preferred to the first output due to it being more readable or understandable. It's also more scalable leading to a lower rate of error. Below is the proof for the reduction formula in Python.
#     </p>
# </div>

# %%
x_sym, n_sym = sp.symbols('x n', real=True, positive=True)

rhs = x_sym * (sp.ln(x_sym))**n_sym - n_sym * sp.integrate((sp.ln(x_sym))**(n_sym - 1), x_sym)

lhs_check = sp.diff(rhs, x_sym)
lhs_check_simplified = sp.simplify(lhs_check)

print("Derivative of the right-hand-side:", lhs_check_simplified)
# Out:
# Derivative of the right-hand-side: -n*log(x)**(n - 1) + n*log(x)**n/log(x) + log(x)**n
